# %% [markdown]
# # Import

# %%
import time
import json
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Code

# %% [markdown]
# ### 4 sizes of batch size to compare the results

# %%
batch_sizes = [32, 64, 128, 256]

# %% [markdown]
# ### Preprocessing

# %%
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

# %% [markdown]
# ### Splitting dataset into train and test sets

# %%
(ds_train_orig, ds_val_orig), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True,
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.3WTMTP_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.3WTMTP_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %% [markdown]
# ### Training

# %%
all_train_losses = {}
all_val_losses = {}
all_train_accuracies = {}
all_val_accuracies = {}
training_times = {}
confusion_matrices = {}

# %%
for batch_size in batch_sizes:
    print(f"\nTraining with batch size: {batch_size}")

    ds_train = ds_train_orig.map(normalize_img).shuffle(1024).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    ds_val = ds_val_orig.map(normalize_img).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # Model
    model = models.Sequential([
        layers.Input(shape=(28, 28, 1)),
        layers.Conv2D(8, kernel_size=2, strides=1, padding="same", activation='relu'),
        layers.MaxPooling2D(pool_size=2, strides=2),
        layers.Dropout(0.3),
        layers.Flatten(),
        layers.Dense(10)
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy']
    )

    early_stop = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

    # Time
    start_time = time.time()
    history = model.fit(
        ds_train,
        epochs=50,
        validation_data=ds_val,
        callbacks=[early_stop],
        verbose=2
    )
    training_time = time.time() - start_time

    # Evaulation
    val_loss, val_acc = model.evaluate(ds_val, verbose=0)

    train_loss = history.history['loss']
    val_loss_hist = history.history['val_loss']
    train_acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    epochs_done = len(train_loss)

    # Prediction and Confusion Matrix
    y_true = []
    y_pred = []

    for images, labels in ds_val:
        logits = model.predict(images, verbose=0)
        preds = np.argmax(logits, axis=1)
        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    cm = confusion_matrix(y_true, y_pred)

    # Saving resulst to JSON file
    results = {
        "train_loss": train_loss,
        "val_loss": val_loss_hist,
        "train_accuracy": train_acc,
        "val_accuracy": val_acc,
        "training_time_seconds": training_time,
        "confusion_matrix": cm.tolist(),
        "epochs_done": epochs_done
    }

    filename = f"/content/[{batch_size}]tf_cnn_results.json"
    with open(filename, "w") as f:
        json.dump(results, f)

    print(f"Results saved: {filename}")
# Out:
# Training with batch size: 32
# Epoch 1/50
# 1875/1875 - 12s - 7ms/step - accuracy: 0.9184 - loss: 0.2706 - val_accuracy: 0.9660 - val_loss: 0.1232
# Epoch 2/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9525 - loss: 0.1559 - val_accuracy: 0.9699 - val_loss: 0.1010
# Epoch 3/50
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9584 - loss: 0.1313 - val_accuracy: 0.9745 - val_loss: 0.0861
# Epoch 4/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9629 - loss: 0.1191 - val_accuracy: 0.9752 - val_loss: 0.0813
# Epoch 5/50
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9657 - loss: 0.1099 - val_accuracy: 0.9765 - val_loss: 0.0749
# Epoch 6/50
# 1875/1875 - 10s - 6ms/step - accuracy: 0.9676 - loss: 0.1043 - val_accuracy: 0.9759 - val_loss: 0.0737
# Epoch 7/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9692 - loss: 0.0994 - val_accuracy: 0.9759 - val_loss: 0.0747
# Epoch 8/50
# 1875/1875 - 10s - 5ms/step - accuracy: 0.9692 - loss: 0.0970 - val_accuracy: 0.9777 - val_loss: 0.0692
# Epoch 9/50
# 1875/1875 - 11s - 6ms/step - accuracy: 0.9708 - loss: 0.0929 - val_accuracy: 0.9779 - val_loss: 0.0676
# Epoch 10/50
# 1875/1875 - 11s - 6ms/step - accuracy: 0.9709 - loss: 0.0931 - val_accuracy: 0.9797 - val_loss: 0.0686
# Epoch 11/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9720 - loss: 0.0900 - val_accuracy: 0.9788 - val_loss: 0.0692
# Epoch 12/50
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9712 - loss: 0.0904 - val_accuracy: 0.9782 - val_loss: 0.0716
# Epoch 13/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9714 - loss: 0.0911 - val_accuracy: 0.9780 - val_loss: 0.0661
# Epoch 14/50
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9727 - loss: 0.0877 - val_accuracy: 0.9796 - val_loss: 0.0670
# Epoch 15/50
# 1875/1875 - 10s - 6ms/step - accuracy: 0.9708 - loss: 0.0894 - val_accuracy: 0.9794 - val_loss: 0.0683
# Epoch 16/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9725 - loss: 0.0858 - val_accuracy: 0.9778 - val_loss: 0.0695
# Epoch 17/50
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9734 - loss: 0.0857 - val_accuracy: 0.9786 - val_loss: 0.0691
# Epoch 18/50
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9736 - loss: 0.0831 - val_accuracy: 0.9792 - val_loss: 0.0667
# Results saved: /content/[32]tf_cnn_results.json
#
# Training with batch size: 64
# Epoch 1/50
# 938/938 - 8s - 9ms/step - accuracy: 0.8995 - loss: 0.3345 - val_accuracy: 0.9552 - val_loss: 0.1574
# Epoch 2/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9379 - loss: 0.2017 - val_accuracy: 0.9630 - val_loss: 0.1247
# Epoch 3/50
# 938/938 - 3s - 4ms/step - accuracy: 0.9450 - loss: 0.1800 - val_accuracy: 0.9687 - val_loss: 0.1090
# Epoch 4/50
# 938/938 - 4s - 5ms/step - accuracy: 0.9495 - loss: 0.1647 - val_accuracy: 0.9684 - val_loss: 0.1050
# Epoch 5/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9506 - loss: 0.1593 - val_accuracy: 0.9716 - val_loss: 0.0970
# Epoch 6/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9527 - loss: 0.1554 - val_accuracy: 0.9716 - val_loss: 0.0953
# Epoch 7/50
# 938/938 - 4s - 5ms/step - accuracy: 0.9548 - loss: 0.1467 - val_accuracy: 0.9701 - val_loss: 0.0964
# Epoch 8/50
# 938/938 - 5s - 5ms/step - accuracy: 0.9538 - loss: 0.1464 - val_accuracy: 0.9733 - val_loss: 0.0918
# Epoch 9/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9566 - loss: 0.1389 - val_accuracy: 0.9736 - val_loss: 0.0905
# Epoch 10/50
# 938/938 - 5s - 5ms/step - accuracy: 0.9563 - loss: 0.1398 - val_accuracy: 0.9730 - val_loss: 0.0916
# Epoch 11/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9560 - loss: 0.1370 - val_accuracy: 0.9725 - val_loss: 0.0933
# Epoch 12/50
# 938/938 - 3s - 4ms/step - accuracy: 0.9568 - loss: 0.1363 - val_accuracy: 0.9726 - val_loss: 0.0950
# Epoch 13/50
# 938/938 - 6s - 6ms/step - accuracy: 0.9590 - loss: 0.1323 - val_accuracy: 0.9744 - val_loss: 0.0910
# Epoch 14/50
# 938/938 - 4s - 4ms/step - accuracy: 0.9587 - loss: 0.1316 - val_accuracy: 0.9748 - val_loss: 0.0888
# Epoch 15/50
# 938/938 - 3s - 4ms/step - accuracy: 0.9587 - loss: 0.1326 - val_accuracy: 0.9734 - val_loss: 0.0928
# Epoch 16/50
# 938/938 - 5s - 5ms/step - accuracy: 0.9599 - loss: 0.1291 - val_accuracy: 0.9741 - val_loss: 0.0903
# Epoch 17/50
# 938/938 - 5s - 5ms/step - accuracy: 0.9585 - loss: 0.1299 - val_accuracy: 0.9741 - val_loss: 0.0906
# Epoch 18/50
# 938/938 - 6s - 6ms/step - accuracy: 0.9592 - loss: 0.1284 - val_accuracy: 0.9749 - val_loss: 0.0913
# Epoch 19/50
# 938/938 - 4s - 5ms/step - accuracy: 0.9598 - loss: 0.1280 - val_accuracy: 0.9751 - val_loss: 0.0898
# Results saved: /content/[64]tf_cnn_results.json
#
# Training with batch size: 128
# Epoch 1/50
# 469/469 - 7s - 15ms/step - accuracy: 0.8967 - loss: 0.3497 - val_accuracy: 0.9521 - val_loss: 0.1679
# Epoch 2/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9387 - loss: 0.2048 - val_accuracy: 0.9618 - val_loss: 0.1301
# Epoch 3/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9457 - loss: 0.1789 - val_accuracy: 0.9631 - val_loss: 0.1188
# Epoch 4/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9503 - loss: 0.1616 - val_accuracy: 0.9679 - val_loss: 0.1079
# Epoch 5/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9547 - loss: 0.1465 - val_accuracy: 0.9705 - val_loss: 0.0960
# Epoch 6/50
# 469/469 - 3s - 5ms/step - accuracy: 0.9574 - loss: 0.1383 - val_accuracy: 0.9725 - val_loss: 0.0888
# Epoch 7/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9613 - loss: 0.1260 - val_accuracy: 0.9735 - val_loss: 0.0834
# Epoch 8/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9635 - loss: 0.1172 - val_accuracy: 0.9742 - val_loss: 0.0820
# Epoch 9/50
# 469/469 - 3s - 5ms/step - accuracy: 0.9643 - loss: 0.1139 - val_accuracy: 0.9747 - val_loss: 0.0763
# Epoch 10/50
# 469/469 - 3s - 5ms/step - accuracy: 0.9650 - loss: 0.1117 - val_accuracy: 0.9769 - val_loss: 0.0750
# Epoch 11/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9673 - loss: 0.1063 - val_accuracy: 0.9763 - val_loss: 0.0759
# Epoch 12/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9677 - loss: 0.1022 - val_accuracy: 0.9774 - val_loss: 0.0720
# Epoch 13/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9676 - loss: 0.1029 - val_accuracy: 0.9754 - val_loss: 0.0751
# Epoch 14/50
# 469/469 - 3s - 7ms/step - accuracy: 0.9672 - loss: 0.1024 - val_accuracy: 0.9783 - val_loss: 0.0717
# Epoch 15/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9685 - loss: 0.0979 - val_accuracy: 0.9781 - val_loss: 0.0706
# Epoch 16/50
# 469/469 - 3s - 5ms/step - accuracy: 0.9688 - loss: 0.0992 - val_accuracy: 0.9776 - val_loss: 0.0731
# Epoch 17/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9695 - loss: 0.0957 - val_accuracy: 0.9791 - val_loss: 0.0669
# Epoch 18/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9698 - loss: 0.0948 - val_accuracy: 0.9774 - val_loss: 0.0701
# Epoch 19/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9709 - loss: 0.0942 - val_accuracy: 0.9783 - val_loss: 0.0695
# Epoch 20/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9709 - loss: 0.0932 - val_accuracy: 0.9783 - val_loss: 0.0693
# Epoch 21/50
# 469/469 - 3s - 7ms/step - accuracy: 0.9702 - loss: 0.0907 - val_accuracy: 0.9781 - val_loss: 0.0681
# Epoch 22/50
# 469/469 - 3s - 6ms/step - accuracy: 0.9707 - loss: 0.0931 - val_accuracy: 0.9774 - val_loss: 0.0691
# Results saved: /content/[128]tf_cnn_results.json
#
# Training with batch size: 256
# Epoch 1/50
# 235/235 - 6s - 26ms/step - accuracy: 0.8807 - loss: 0.4477 - val_accuracy: 0.9512 - val_loss: 0.1806
# Epoch 2/50
# 235/235 - 7s - 29ms/step - accuracy: 0.9440 - loss: 0.1903 - val_accuracy: 0.9643 - val_loss: 0.1249
# Epoch 3/50
# 235/235 - 3s - 11ms/step - accuracy: 0.9566 - loss: 0.1498 - val_accuracy: 0.9696 - val_loss: 0.1042
# Epoch 4/50
# 235/235 - 2s - 10ms/step - accuracy: 0.9597 - loss: 0.1334 - val_accuracy: 0.9720 - val_loss: 0.0957
# Epoch 5/50
# 235/235 - 3s - 13ms/step - accuracy: 0.9628 - loss: 0.1229 - val_accuracy: 0.9729 - val_loss: 0.0924
# Epoch 6/50
# 235/235 - 2s - 10ms/step - accuracy: 0.9640 - loss: 0.1176 - val_accuracy: 0.9753 - val_loss: 0.0827
# Epoch 7/50
# 235/235 - 2s - 10ms/step - accuracy: 0.9657 - loss: 0.1111 - val_accuracy: 0.9760 - val_loss: 0.0805
# Epoch 8/50
# 235/235 - 2s - 9ms/step - accuracy: 0.9658 - loss: 0.1097 - val_accuracy: 0.9762 - val_loss: 0.0797
# Epoch 9/50
# 235/235 - 2s - 9ms/step - accuracy: 0.9671 - loss: 0.1050 - val_accuracy: 0.9756 - val_loss: 0.0784
# Epoch 10/50
# 235/235 - 3s - 12ms/step - accuracy: 0.9679 - loss: 0.1000 - val_accuracy: 0.9759 - val_loss: 0.0794
# Epoch 11/50
# 235/235 - 5s - 19ms/step - accuracy: 0.9679 - loss: 0.1023 - val_accuracy: 0.9779 - val_loss: 0.0744
# Epoch 12/50
# 235/235 - 2s - 10ms/step - accuracy: 0.9691 - loss: 0.0985 - val_accuracy: 0.9781 - val_loss: 0.0748
# Epoch 13/50
# 235/235 - 2s - 10ms/step - accuracy: 0.9690 - loss: 0.0977 - val_accuracy: 0.9771 - val_loss: 0.0749
# Epoch 14/50
# 235/235 - 4s - 16ms/step - accuracy: 0.9697 - loss: 0.0957 - val_accuracy: 0.9766 - val_loss: 0.0778
# Epoch 15/50
# 235/235 - 4s - 16ms/step - accuracy: 0.9707 - loss: 0.0922 - val_accuracy: 0.9781 - val_loss: 0.0746
# Epoch 16/50
# 235/235 - 2s - 9ms/step - accuracy: 0.9703 - loss: 0.0942 - val_accuracy: 0.9785 - val_loss: 0.0762
# Results saved: /content/[256]tf_cnn_results.json
